# %% [markdown]
# # Assignment: Linear Regression

# %% [markdown]
# ## Import the required packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Function to calculate the Gradiend descent

# %%
## m _ number of training samples
## alpha - learning rate 
def gradientDescent(x, y, theta, alpha, m, maxsteps):
    thetaHist=np.empty([maxsteps, 2])
    xTrans = x.transpose()
    for i in range(0, maxsteps):
        h = np.dot(x,theta)
        theta = theta - alpha*(1/m)*(np.dot(xTrans,h-y))
        thetaHist[i] = theta
   
    return theta, thetaHist

##function that computes hypothesis values for samples
def multiply_matrix(x,theta):
    multiplied = []
    for i in range(len(x)):
        multiplied.append(x[i] * theta)
    return multiplied

# %% [markdown]
# ## Function to calcultate the cost function

# %%
def costFunction(x, y, theta):
    cost = 0
    m, n = np.shape(x)
    for i in range(m): 
            error = (np.dot(x,theta)[i]-y[i])**2
            cost += error
    cost = cost * (1/(2*m))    
    return cost

# %% [markdown]
# ## Define some training data
# To test your algorithm it is a good idea to start with very simple test data where you know the right answer. So let's put all data points on a line first. Feel free to play this test data.

# %%
x=np.array([[1, 0], [1, 0.5], [1, 1], [1, 1.5], [1, 2], [1, 2.5], [1, 3], [1, 4], [1, 5]])
y=np.array([0, 0.5, 1, 1.5, 2, 2.5, 3, 4, 5])

# %% [markdown]
# ## Calculate length of training set

# %%
m, n = np.shape(x)

# %% [markdown]
# ## Plot training set

# %%
fig = plt.figure(1)  # An empty figure with no axes
plt.plot(x[:,1], y, 'x')

# %% [markdown]
# ## Cost function
# Also it is useful for simple test cases to not just run an optimization but first to do a systematic search. So let us first calculate the values of the cost function for different parameters theta

# %%
import numpy as np
theta0 = np.arange(-2, 2.01, 0.25)
theta1 = np.arange(-2, 3.01, 0.25)

# Calculate values of the cost function
cost_theta0 = 0
cost_theta1 = 0
index = 0
J = np.empty([len(theta0),len(theta1)])
for i in range(0, len(theta0)):  
    for j in range(0, len(theta1)):
        theta = [theta0[i],theta1[j]]
        J[i,j] = costFunction(x,y,theta)

# %% [markdown]
# ## Visualize the cost function
# Let us do some test plots to see the cost function J and to analyze how it depends on the parameters theta0 and theta1

# %%
theta0, theta1 = np.meshgrid(theta0, theta1)
fig2 = plt.figure(2)
ax = fig2.add_subplot(121, projection="3d")
surf = ax.plot_surface(theta0, theta1, np.transpose(J))
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')
ax.set_zlabel('Cost J')
ax.set_title('Cost function Surface plot')

ax = fig2.add_subplot(122)
contour = ax.contour(theta0, theta1, np.transpose(J))
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')
ax.set_title('Cost function Contour plot')

fig2.subplots_adjust(bottom=0.1, right=1.5, top=0.9)

# %% [markdown]
# ## Gradient descent implementation
# Here we implement Gradient Descent

# %%
alpha = 0.05        # learning parameter
maxsteps= 1000      # number of iterations that the algorithm is running

# First estimates for our parameters
thet = [2, 0]

thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)

# %% [markdown]
# ## Print found optimal values

# %%
print("Optimized Theta0 is ", thet[0])
print("Optimized Theta1 is ", thet[1])
# Out:
# Optimized Theta0 is  3.9852928379029545e-07
# Optimized Theta1 is  0.9999998725702243

# %% [markdown]
# ## Visualization of the solution
# Now let's plot the found solutions of the Gradient Descent algorithms on the contour plot of our cost function to see how it approaches the desired minimum.

# %%
fig3 = plt.figure(3)
plt.contour(theta0, theta1, np.transpose(J))
plt.plot(thetaHist[:,0], thetaHist[:,1], 'x')
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')

# Finally, let's plot the hypothesis function into our data
xs = np.array([x[0,1], x[x.shape[0]-1,1]])
h = np.array([[thet[1] * xs[0] + thet[0]], [thet[1] * xs[1] + thet[0]]])
plt.figure(1)
plt.plot(x[:,1], y, 'x')  # Data
plt.plot(xs, h, '-o')     # hypothesis function
plt.show()

# %% [markdown]
# ### Question 1

# %%
##set learning rate to a very small number
alpha = 0.0001

###########################################
## repeat the same process
maxsteps= 1000      # number of iterations that the algorithm is running

# First estimates for our parameters
thet = [2, 0]
thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
fig3 = plt.figure(3)
plt.contour(theta0, theta1, np.transpose(J))
plt.plot(thetaHist[:,0], thetaHist[:,1], 'x')
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')

# Finally, let's plot the hypothesis function into our data
xs = np.array([x[0,1], x[x.shape[0]-1,1]])
h = np.array([[thet[1] * xs[0] + thet[0]], [thet[1] * xs[1] + thet[0]]])
plt.figure(1)
plt.plot(x[:,1], y, 'x')  # Data
plt.plot(xs, h, '-o')     # hypothesis function
plt.show()

# %% [markdown]
# > A too small learning rate could lead to higher evaluation of the cost function and slows down the convergence of the theta values to their minimum values. As seen from the plotted results, if we set the learning rate to a too small number such as 0.0001, we can observe that the hypothesis function does not fit the data well.

# %% [markdown]
# ### Question 2

# %%
##set learning rate to a large number
alpha = 0.27

###########################################
## repeat the same process
maxsteps= 1000      # number of iterations that the algorithm is running

# First estimates for our parameters
thet = [2, 0]
thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
fig3 = plt.figure(3)
plt.contour(theta0, theta1, np.transpose(J))
plt.plot(thetaHist[:,0], thetaHist[:,1], 'x')
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')

# Finally, let's plot the hypothesis function into our data
xs = np.array([x[0,1], x[x.shape[0]-1,1]])
h = np.array([[thet[1] * xs[0] + thet[0]], [thet[1] * xs[1] + thet[0]]])
plt.figure(1)
plt.plot(x[:,1], y, 'x')  # Data
plt.plot(xs, h, '-o')     # hypothesis function
plt.show()

# %% [markdown]
# > Too large learning rates could also cause higher costs and avoid fast convergence of gradient descent algorithm. As seen in the plotted results, we can see that our estimates of theta values do not perform well in this case.

# %% [markdown]
# ### Question 3
# > Linear Regression can indeed find the global minimum, however this is not always the case. Gradient descent algorithm by its nature always seeks to find a local optimum point. It can continue looking for another possibly global optimal value if it exists, however, as the algorithm is iterative, if we have a big step size, the algorithm may skip a potential global optimum.

# %% [markdown]
# ### Question 4

# %%
##set learning rate to a very small number
alpha = 0.05

###########################################
## repeat the same process
maxsteps= 1000      # number of iterations that the algorithm is running

# Set thet[0] and thet[1] to ssomething completely off 
thet = [5, -2]
thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
fig3 = plt.figure(3)
plt.contour(theta0, theta1, np.transpose(J))
plt.plot(thetaHist[:,0], thetaHist[:,1], 'x')
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')

# Finally, let's plot the hypothesis function into our data
xs = np.array([x[0,1], x[x.shape[0]-1,1]])
h = np.array([[thet[1] * xs[0] + thet[0]], [thet[1] * xs[1] + thet[0]]])
plt.figure(1)
plt.plot(x[:,1], y, 'x')  # Data
plt.plot(xs, h, '-o')     # hypothesis function
plt.show()

# %% [markdown]
# >As seen in the plotted results, if we set the initial estimates for theta to something irrelevant, we can see that the convergence of the gradient descent to a minimum value takes more steps, since we need to take additional steps to approach to our goal estimates.

# %% [markdown]
# ### Question 5

# %%
alpha = 0.05        # learning parameter
maxsteps= 1000      # number of iterations that the algorithm is running

# First estimates for our parameters
thet = [2, 0]

thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-d71d8793e29c> in <module>
#       5 thet = [2, 0]
#       6
# ----> 7 thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
#
# <ipython-input-151-bddb16536b69> in gradientDescent(x, y, theta, alpha, m, maxsteps)
#       5         h = np.dot(x,theta)
#       6         theta[0]= theta[0] - alpha*(1/m)*(np.dot(xTrans,h-y))
# ----> 7         thetaHist[i] = theta
#       8     for i in range(0, maxsteps):
#       9         h = np.dot(x,theta)
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# #### Question 6

# %%
alpha = 0.05        # learning parameter
maxsteps= 250   # number of iterations that the algorithm is running

# First estimates for our parameters
thet = [2, 0]

thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)

thet = [2, 0]
thet, thetaHist = gradientDescent(x, y, thet, alpha, m, maxsteps)
fig3 = plt.figure(3)
plt.contour(theta0, theta1, np.transpose(J))
plt.plot(thetaHist[:,0], thetaHist[:,1], 'x')
ax.set_xlabel('theta 0')
ax.set_ylabel('theta 1')
# Finally, let's plot the hypothesis function into our data
xs = np.array([x[0,1], x[x.shape[0]-1,1]])
h = np.array([[thet[1] * xs[0] + thet[0]], [thet[1] * xs[1] + thet[0]]])
plt.figure(1)
plt.plot(x[:,1], y, 'x')  # Data
plt.plot(xs, h, '-o')     # hypothesis function
plt.show()

# %% [markdown]
# > As seen from the code above, if we set the maximum amount of iterations to 250, we reach the correct exact values of theta0 and theta1.
